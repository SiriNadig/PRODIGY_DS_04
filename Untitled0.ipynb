# %% [markdown]
# <a href="https://colab.research.google.com/github/SiriNadig/PRODIGY_DS_04/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from textblob import TextBlob
import matplotlib.pyplot as plt
from wordcloud import WordCloud, STOPWORDS

# %%
from google.colab import drive
drive.mount('/content/drive')

file_path = '/content/drive/My Drive/Colab Notebooks/Financial_Data.csv'

import pandas as pd
df = pd.read_csv(file_path)
# Out:
# Mounted at /content/drive

# %%
finance_texts = df['Sentence'].astype(str).tolist()
Sentiment = []

# %%
if 'Sentiment' not in df.columns:
    for tweet_text in tweet_texts:
        analysis = TextBlob(tweet_text)
        sentiments.append(analysis.sentiment.polarity)
    df['Sentiment'] = sentiments
else:
    sentiments = df['Sentiment'].tolist()

# %%
# Visualize sentiment distribution
plt.hist(df["Sentiment"], bins=10)
plt.xlabel("Sentiment Polarity")
plt.ylabel("Frequency")
plt.title("Sentiment Distribution")
plt.show()

# %%
# Creating a word cloud
all_words = " ".join(finance_texts )
wordcloud = WordCloud(width=800, height=500, random_state=21, max_font_size=110).generate(all_words)
plt.figure(figsize=(10, 7))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()
